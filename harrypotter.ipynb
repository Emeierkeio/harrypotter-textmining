# %% [markdown]
# # Harry Potter Corpus - Topic Modeling
#
# ######https://github.com/ErikaJacobs/Harry-Potter-Text-Mining
#
# ---
#
# ### Abstract:
# Prova
#
# ---
#
#
# Students:
#
# * Aurora Cerabolini (839327)
# * Corinna Strada (839193)
# * Mirko Tritella (887196)

# %%
CONSTANT:

DATASET = "https://www.kaggle.com/datasets/balabaskar/harry-potter-books-corpora-part-1-7?select=Book.txt"

# %% [markdown]
# ## Dataset

# %% [markdown]
# ## Text Pre-processing

# %% [markdown]
# ### Tokenization

# %% [markdown]
# ### Normalization

# %% [markdown]
# ### Lemmatization or Stemming

# %% [markdown]
# ### Stop Words Removal

# %% [markdown]
# ## Text Representation

# %% [markdown]
# ## Topic Modeling

# %% [markdown]
# ### Evaluation

# %% [markdown]
# ## Text Summarization

# %% [markdown]
# ### Evaluation
